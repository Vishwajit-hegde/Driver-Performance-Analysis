# %%
import pandas as pd
from numpy import *
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
#severity 1 data
gyr = pd.read_csv("/home/tanay/Downloads/temp_val.csv", header =None)
acc =pd.read_csv("/home/tanay/Downloads/accel_values.csv", header = None)

# %%
gyr.columns = ["time","z","runId","turnId","aggresive"]

# %%
gyr = gyr.fillna(999)

# %%
gyr["z"] = gyr["z"].rolling(20).mean()[20:]

# %%
gyr.head(30)
# Out:
#              time         z  runId  turnId  aggresive
# 0   1408346730004       NaN      1      23          0
# 1   1408346730055       NaN      1      23          0
# 2   1408346730106       NaN      1      23          0
# 3   1408346730155       NaN      1      23          0
# 4   1408346730205       NaN      1      23          0
# 5   1408346730254       NaN      1      23          0
# 6   1408346730305       NaN      1      23          0
# 7   1408346730354       NaN      1      23          0
# 8   1408346730404       NaN      1      23          0
# 9   1408346730455       NaN      1      23          0
# 10  1408346730505       NaN      1      23          0
# 11  1408346730555       NaN      1      23          0
# 12  1408346730604       NaN      1      23          0
# 13  1408346730655       NaN      1      23          0
# 14  1408346730708       NaN      1      23          0
# 15  1408346730754       NaN      1      23          0
# ...

# %%
gyr=gyr[gyr.aggresive==0]

# %%
gyr.turnId.unique()
# Out:
# array([23, 24, 27, 30, 32, 34, 40, 41, 46, 47, 52, 57, 60, 61, 62, 63, 22,
#        25])

# %%
df= gyr.groupby("turnId")

# %%
run4= df.get_group(61)
t = run4.groupby("runId")

# %%
run4.runId.unique()
# Out:
# array([1, 3, 4, 5, 6, 7, 8, 9])

# %%
fig = make_subplots(rows=1, cols=1)
fig.append_trace(go.Scatter(y=t.get_group(1).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(3).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(4).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(5).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(8).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(7).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(6).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(9).z.values), row=1, col=1)
fig.show()
# Out:
# <div>
#
#
#             <div id="bf1e8af8-5bb4-4cb2-bcf6-4e376f4d6395" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bf1e8af8-5bb4-4cb2-bcf6-4e376f4d6395")) {
#                     Plotly.newPlot(
#                         'bf1e8af8-5bb4-4cb2-bcf6-4e376f4d6395',
# ...

# %%
t.get_group(7).z.values.shape
# Out:
# (239,)

# %%
sum2 = np.zeros(239)
for i in [1,3,4,5,6,7,8,9]:
    sum2 = sum2+ t.get_group(i).z.values[:239]
sum2 = sum2/6

# %% [markdown]
# Template for bend severity #2

# %%
fig = make_subplots(rows=1, cols=1)
fig.append_trace(go.Scatter(y=sum2), row=1, col=1)
fig.show()
# Out:
# <div>
#
#
#             <div id="3f74246f-037d-44d3-83b5-48201550ceee" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3f74246f-037d-44d3-83b5-48201550ceee")) {
#                     Plotly.newPlot(
#                         '3f74246f-037d-44d3-83b5-48201550ceee',
# ...

# %%
#severity 2 data
gyr3 = pd.read_csv("/home/tanay/Downloads/temp2_val.csv", header =None)
gyr3.columns = ["time","z","runId","turnId","aggresive"]

# %%
gyr3["z"] = gyr3["z"].rolling(20).mean()[20:]

# %%
gyr3=gyr3[gyr3.aggresive==0]

# %%
gyr3.turnId.unique()
# Out:
# array([77,  4,  6,  8, 13, 17, 10])

# %%
df= gyr3.groupby("turnId")
run4= df.get_group(4)
t = run4.groupby("runId")
run4.runId.unique()
# Out:
# array([2, 3, 4, 5, 8, 9])

# %%
fig = make_subplots(rows=1, cols=1)
fig.append_trace(go.Scatter(y=t.get_group(2).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(3).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(5).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(4).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(8).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(9).z.values), row=1, col=1)
fig.show()
# Out:
# <div>
#
#
#             <div id="3b7bd75a-ef27-41c2-b601-21697e3ed227" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3b7bd75a-ef27-41c2-b601-21697e3ed227")) {
#                     Plotly.newPlot(
#                         '3b7bd75a-ef27-41c2-b601-21697e3ed227',
# ...

# %%
temp3 = np.zeros(135)
for i in [2, 3, 4, 5, 8, 9]:
    temp3 = temp3+ t.get_group(i).z.values[:135]
temp3 = temp3/6

# %% [markdown]
# Template For bend Severity #3

# %%
fig = make_subplots(rows=1, cols=1)
fig.append_trace(go.Scatter(y=temp3), row=1, col=1)
fig.show()
# Out:
# <div>
#
#
#             <div id="b38be008-909d-4050-add0-cdc478ac9263" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b38be008-909d-4050-add0-cdc478ac9263")) {
#                     Plotly.newPlot(
#                         'b38be008-909d-4050-add0-cdc478ac9263',
# ...

# %%
#severity 3 data
gyr2 = pd.read_csv("/home/tanay/Downloads/temp3_vals.csv", header =None)
gyr2.columns = ["time","z","runId","turnId","aggresive"]
gyr2["z"] = gyr2["z"].rolling(20).mean()[20:]

# %%
gyr2=gyr2[gyr2.aggresive==1]

# %%
gyr2.turnId.unique()
# Out:
# array([35, 45, 49, 50, 12, 14, 29, 37, 39, 42, 51, 53, 59, 55, 56, 54, 68,
#        71, 33, 36])

# %%
df= gyr2.groupby("turnId")
run4= df.get_group(33)
t = run4.groupby("runId")
run4.runId.unique()
# Out:
# array([7])

# %%
fig = make_subplots(rows=1, cols=1)
fig.append_trace(go.Scatter(y=t.get_group(3).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(8).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(5).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(2).z.values), row=1, col=1)
fig.append_trace(go.Scatter(y=t.get_group(9).z.values), row=1, col=1)
fig.show()
# Out:
# <div>
#
#
#             <div id="8dab133a-1fa3-4f60-bdbe-82b21995eaea" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8dab133a-1fa3-4f60-bdbe-82b21995eaea")) {
#                     Plotly.newPlot(
#                         '8dab133a-1fa3-4f60-bdbe-82b21995eaea',
# ...

# %%
temp2 = np.zeros(266)
for i in [2, 3, 5, 6, 8, 9]:
    temp2 = temp2+ t.get_group(i).z.values[:266]
temp2 = temp2/6

# %% [markdown]
# Template for bend severity #2

# %%
fig = make_subplots(rows=1, cols=1)
fig.append_trace(go.Scatter(y=temp2), row=1, col=1)
fig.show()
# Out:
# <div>
#
#
#             <div id="07ce1816-5058-4d81-a70a-f0c4cb36f442" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("07ce1816-5058-4d81-a70a-f0c4cb36f442")) {
#                     Plotly.newPlot(
#                         '07ce1816-5058-4d81-a70a-f0c4cb36f442',
# ...
